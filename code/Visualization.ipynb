# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt

# Data extracted from the provided table
steps = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000]
training_loss = [4.076200, 3.399100, 3.333200, 3.344800, 3.357300, 3.345100, 3.303300, 3.332900, 3.399000, 3.320600, 3.349700, 3.344000]
validation_loss = [3.339734, 3.323186, 3.343100, 3.316158, 3.319942, 3.312574, 3.313578, 3.311939, 3.326062, 3.313354, 3.312037, 3.311300]

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(steps, training_loss, label="Training Loss", marker='o')
plt.plot(steps, validation_loss, label="Validation Loss", marker='o', linestyle='--')

# Adding labels and title
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Provided dataset
steps = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000]
training_loss = [4.976200, 2.798400, 2.536100, 2.366700, 2.242700, 2.116500, 2.007200, 1.944600, 1.809200, 1.670200, 1.582100, 1.579500]
validation_loss = [2.859481, 2.561285, 2.298822, 2.132559, 2.026144, 1.931902, 1.794211, 1.695302, 1.655811, 1.580696, 1.499800, 1.467293]

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(steps, training_loss, label="Training Loss", marker='o')
plt.plot(steps, validation_loss, label="Validation Loss", marker='o', linestyle='--')

# Adding labels and title
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()
