# %%
# Libararies
import torch
import os
import re
from pydub import AudioSegment
from demucs.pretrained import get_model
from demucs.apply import apply_model
from demucs.separate import load_track
import librosa
import soundfile

# %%
dataset_path = '/home/kangyi/Lyrics-audio-Alignment/dataset/songs_en'
lang = "en-US"

PRE_PROCESSED = True
ORIGINAL_SR = 44100
TARGET_SR = 16000

# %%
# Return pytorch device
def select_device(mps_enable = True):
    if torch.cuda.is_available():
        return torch.device('cuda')     # CUDA
    elif torch.backends.mps.is_available() & mps_enable: 
        return torch.device('mps')    # Apple Sillicon
    else:
        return torch.device("cpu")    # CPU

# %%
def remove_special_characters(filename):
    # Replace all non-alphanumeric characters (except for dots and underscores) with an empty string
    return re.sub(r'[^a-zA-Z0-9_.-]', '', filename)

# Get filenames
# Get a list of file names in the directory
file_names_lrc = os.listdir(dataset_path + os.sep + 'lrc_processed')
file_names_songs = os.listdir(dataset_path + os.sep + 'songs')
file_names_lrc_processed = [remove_special_characters(os.path.splitext(file)[0]) for file in file_names_lrc]
file_names_songs_processed = [remove_special_characters(os.path.splitext(file)[0]) for file in file_names_songs]

file_names_lrc_idx = []
file_names_songs_idx = []
for i in range(len(file_names_lrc_processed)):
    for j in range(len(file_names_songs_processed)):
        if file_names_lrc_processed[i] == file_names_songs_processed[j]:
            if file_names_lrc_processed[i] != '':
                file_names_lrc_idx.append(file_names_lrc[i])
                file_names_songs_idx.append(file_names_songs[j])
            continue
len(file_names_lrc_idx)
# Out:
# 281

# %%
if not os.path.exists('dataset/output-en'):
    os.makedirs('dataset/output-en')
    os.makedirs('dataset/output-en' + os.sep + 'vocal')

# Extract Vocals
# Select Device
device = select_device()
print("Device Selected:", device)

output_path = "/home/kangyi/Lyrics-audio-Alignment/dataset/output-en"

# Choose Demucs Model for Vocals Extraction
demucs_model = get_model(name="htdemucs", repo=None)
demucs_model.to(device)
demucs_model.eval()
vocals_source_idx = demucs_model.sources.index("vocals")
sample_rate = demucs_model.samplerate

for i in range(len(file_names_songs_idx)):
    song_path_abs = dataset_path + os.sep + 'songs' + os.sep + file_names_songs_idx[i]
    vocal_path = output_path + os.sep + 'vocal' + os.sep + os.path.splitext(file_names_songs_idx[i])[0] + "_vocal.wav"
    if os.path.exists(vocal_path) or os.path.splitext(file_names_songs_idx[i])[-1] != '.ogg':
        continue
    # Load Aduio Track
    print(f"Loaded {song_path_abs}")
    audio_track = load_track(song_path_abs, 2, sample_rate)

    # Extract Vocal
    ref = audio_track.mean(0)
    audio_track_nor = (audio_track - ref.mean()) / ref.std() # Normalization
    with torch.no_grad():
        sources = apply_model(demucs_model, audio_track_nor[None], device=device, shifts=1, split=True, overlap=0.25, progress=False)
    track_vocal = sources[0][vocals_source_idx].cpu().numpy()[0, ...]

    # Post-processing
    track_vocal = librosa.resample(track_vocal, orig_sr=ORIGINAL_SR, target_sr=TARGET_SR)

    # Write to Output
    try:
        soundfile.write(vocal_path, track_vocal, TARGET_SR)
    except Exception as e:
        print(f"An error occurred: {e}")
        print(f"Converted {file_names_songs_idx[i]} to {vocal_path}")
    print(f"{i+1}/{len(file_names_songs_idx)}")
# Out:
# Device Selected: cuda

# %%
# Helper Function to convert time
def timestamp_to_seconds(ts_str):
    # ts_str format: "MM:SS.xxx"
    minutes, rest = ts_str.split(":")
    seconds = float(rest)
    total_seconds = int(minutes)*60 + seconds
    return total_seconds

files = []
lines = []

# Create folders if not exits
if not os.path.exists('dataset/output-en' + os.sep + 'splits'):
    os.makedirs('dataset/output-en' + os.sep + 'splits')

# Go through all of them
for idx in range(len(file_names_lrc_idx)):
    # Make sure it is lrc file
    if os.path.splitext(file_names_songs_idx[idx])[-1] != '.ogg':
        continue

    # Parse Lrc Files
    pattern = r'\[([0-9]{2}:[0-9]{2}\.[0-9]{3})\]([^[]*)'
    parsed_data = []
    lrc_path_abs = dataset_path + os.sep + 'lrc_processed' + os.sep + file_names_lrc_idx[idx]
    print(file_names_lrc_idx[idx])
    with open(lrc_path_abs, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            matches = re.findall(pattern, line)
            lyrics_line = ''
            for i in range(len(matches)):
                lyrics_line = lyrics_line + matches[i][1].strip() + ' '
            parsed_data.append((matches[0][0], matches[len(matches)-1][0], lyrics_line.strip()))

    line_segments = [(timestamp_to_seconds(ts1), timestamp_to_seconds(ts2), txt) for ts1, ts2, txt in parsed_data]

    # Export all the segments
    vocal_path = output_path + os.sep + 'vocal' + os.sep + os.path.splitext(file_names_songs_idx[idx])[0] + "_vocal.wav"
    audio = AudioSegment.from_wav(vocal_path)
    audio_duration = len(audio) / 1000.0

    for idy, (start, end, line) in enumerate(line_segments):
        segment_audio = audio[start*1000 : end*1000]  # pydub uses milliseconds
        segment_filename = output_path + os.sep + 'splits' + os.sep + os.path.splitext(file_names_songs_idx[idx])[0] + f"_vocal_{idy:05d}.wav"
        files.append(segment_filename)
        lines.append(line)
        segment_audio.export(segment_filename, format="wav")
# Out:
# Taylor Swift - Blank Space.lrc
# Evanescence - Bring Me To Life.lrc
# Christina Perri - A Thousand Years.lrc
# Meghan Trainor - Me Too.lrc
# Selena Gomez - Come & Get It.lrc
# Linkin Park - In The End.lrc
# Carly Rae Jepsen - Call Me Maybe.lrc
# Zara Larsson - Lush Life.lrc
# Beyoncé - Love On Top.lrc
# Taylor Swift - I Knew You Were Trouble.lrc
# Eminem - Like Toy Soldiers.lrc
# One Direction - History.lrc
# Bastille - Pompeii.lrc
# Rihanna - Don't Stop The Music (Jody den Broeder).lrc
# Mariah Carey - We Belong Together.lrc
# Katy Perry - This Is How We Do.lrc
# One Direction - What Makes You Beautiful.lrc
# Little Mix - Black Magic.lrc
# Israel Kamakawiwo Ole - Over The Rainbow.lrc
# AC⁄DC - Back In Black.lrc
# French Montana - Feeling Myself.lrc
# Avril Lavigne - What The Hell.lrc
# Britney Spears - I Wanna Go.lrc
# Tove Lo - Habits (Stay High) (Oliver Nelson Remix).lrc
# Sean Kingston - Beautiful Girls.lrc
# Justin Bieber - Sorry.lrc
# Justin Timberlake - Mirrors.lrc
# Post Malone - White Iverson (Clean).lrc
# Shawn Mendes - Stitches.lrc
# Lana Del Rey - Summertime Sadness.lrc
# John Newman - Love Me Again (Kove Remix).lrc
# Linkin Park - New Divide.lrc
# Queen - Bohemian rhapsody.lrc
# Beyoncé - Crazy In Love.lrc
# LMFAO - Sorry For Party Rocking.lrc
# Avicii - The Nights.lrc
# Miley Cyrus - We Can't Stop.lrc
# Charlie Puth - One Call Away.lrc
# Iggy Azalea - Work.lrc
# Akon - Smack That.lrc
# Nelly - Just A Dream.lrc
# Katy Perry - Firework.lrc
# Nico & Vinz - Am I Wrong.lrc
# Bruno Mars - 24K Magic.lrc
# Survivor - Eye of the Tiger.lrc
# Rihanna - Take A Bow.lrc
# Marshmello - Alone.lrc
# AC⁄DC - Thunderstruck.lrc
# Ariana Grande - One Last Time.lrc
# Rihanna - Russian Roulette.lrc
# Black Eyed Peas - My Humps.lrc
# Ye - Stronger.lrc
# One Direction - Story of My Life.lrc
# Soulja Boy - Crank That (Soulja Boy) (Travis Barker Remix).lrc
# Whitney Houston - I Will Always Love You.lrc
# Justin Bieber - Somebody To Love.lrc
# Ed Sheeran - Thinking Out Loud.lrc
# Selena Gomez - The Heart Wants What It Wants.lrc
# Taylor Swift - Style.lrc
# Meghan Trainor - Dear Future Husband.lrc
# Crazy Frog - Axel F.lrc
# Adele - Skyfall.lrc
# Nirvana - Smells Like Teen Spirit (Single Version).lrc
# Katy Perry - Part Of Me.lrc
# Rihanna - Diamonds (Album Version).lrc
# Rihanna - Rude Boy.lrc
# Michael Jackson - Beat It.lrc
# Justin Bieber - Boyfriend.lrc
# WALK THE MOON - Shut Up And Dance.lrc
# OneRepublic - Counting Stars.lrc
# Nicki Minaj - Starships.lrc
# Meghan Trainor - Lips Are Movin.lrc
# Michael Jackson - Billie Jean.lrc
# Jennifer Lopez - Papi.lrc
# Duke Dumont - Ocean Drive.lrc
# Drake - Hotline Bling.lrc
# Wiz Khalifa - Black And Yellow (G-Mix,explicit).lrc
# Coldplay - Viva la Vida.lrc
# Adele - Set Fire to the Rain.lrc
# Passenger - Let Her Go.lrc
# Rihanna - Unfaithful (Album Version).lrc
# Avril Lavigne - When You're Gone.lrc
# Coldplay - Paradise.lrc
# Lana Del Rey - Born To Die.lrc
# Kiesza - Hideaway.lrc
# Charli xcx - Boom Clap.lrc
# Ellie Goulding - Love Me Like You Do.lrc
# Galantis - No Money.lrc
# Beyoncé - Best Thing I Never Had.lrc
# The Chainsmokers - #SELFIE.lrc
# Jessie J - Domino.lrc
# Shakira - She Wolf (Album Version).lrc
# Lady Gaga - Bad Romance.lrc
# Aerosmith - Crazy.lrc
# Justin Bieber - Love Yourself.lrc
# Guns N' Roses - Paradise City.lrc
# Bon Jovi - Always.lrc
# Shakira - Whenever, Wherever.lrc
# The Script - Hall of Fame.lrc
# Sia - Chandelier.lrc
# Meghan Trainor - All About That Bass.lrc
# David Guetta - Without You.lrc
# Maroon 5 - Animals.lrc
# Red Hot Chili Peppers - Californication.lrc
# Ellie Goulding - On My Mind.lrc
# Ed Sheeran - Give Me Love.lrc
# Rihanna - Where Have You Been.lrc
# Guns N' Roses - Sweet Child O'Mine.lrc
# 50 Cent - In Da Club.lrc
# David Guetta - Play Hard.lrc
# Bon Jovi - It's My Life.lrc
# Wiz Khalifa - Roll Up.lrc
# Taylor Swift - 22.lrc
# Rihanna - California King Bed (Album Version).lrc
# Shawn Mendes - Treat You Better.lrc
# LMFAO - Sexy and I Know It.lrc
# Selena Gomez - Kill Em With Kindness.lrc
# Lady Gaga - Poker Face.lrc
# 3 Doors Down - Here Without You.lrc
# One Direction - Drag Me Down.lrc
# Maroon 5 - Misery.lrc
# Eminem - Mockingbird.lrc
# Demi Lovato - Cool for the Summer (Explicit).lrc
# Hozier - Take Me to Church.lrc
# The Verve - Bitter Sweet Symphony (Radio Edit).lrc
# Evanescence - My Immortal (Band Version).lrc
# Spice Girls - Wannabe (Radio Edit).lrc
# Beyoncé - Run The World (Girls) (Dave Aude Club Remix).lrc
# Mariah Carey - All I Want for Christmas Is You.lrc
# Flo Rida - Whistle.lrc
# Beyoncé - Single Ladies (Put a Ring on It).lrc
# Beyoncé - Beautiful Liar.lrc
# Ariana Grande - Into You.lrc
# Galantis - Runaway (U & I).lrc
# John Legend - All of Me.lrc
# Era Istrefi - Bonbon.lrc
# Culture Club - Karma Chameleon.lrc
# The Weeknd - Can't Feel My Face.lrc
# Coldplay - The Scientist.lrc
# Cyndi Lauper - Girls Just Want to Have Fun.lrc
# Alicia Keys - No One.lrc
# Jon Bon Jovi - Livin On A Prayer.lrc
# Eminem - Rap God.lrc
# Jason Derulo - Want to Want Me.lrc
# Maroon 5 - Sugar.lrc
# Enrique Iglesias - Hero.lrc
# Jennifer Lopez - Ain't Your Mama.lrc
# Justin Bieber - I'll Show You.lrc
# P!NK - So What.lrc
# Katy Perry - Hot N Cold.lrc
# Lorde - Royals.lrc
# Calvin Harris - Summer.lrc
# One Direction - Steal My Girl.lrc
# No Doubt - Don't Speak.lrc
# Shakira - Waka Waka (This Time For Africa) (K-Mix).lrc
# Sam Smith - Stay With Me.lrc
# Lil Wayne - Lollipop.lrc
# Rachel Platten - Fight Song.lrc
# Bruno Mars - Locked Out of Heaven.lrc
# One Direction - Little Things.lrc
# Avicii - Wake Me Up (Radio Edit).lrc
# Anna Kendrick - Cups (Pitch Perfect’s “When I’m Gone”) (Pop Version).lrc
# Linkin Park - Numb.lrc
# Michael Jackson - Thriller.lrc
# Adele - Someone Like You.lrc
# Maroon 5 - One More Night.lrc
# Black Eyed Peas - The Time(Dirty Bit).lrc
# ZAYN - PILLOWTALK.lrc
# Wiz Khalifa - We Dem Boyz.lrc
# Britney Spears - Toxic.lrc
# The Police - Every Breath You Take.lrc
# Chris Brown - With You.lrc
# Selena Gomez - Slow Down.lrc
# Coldplay - A Sky Full Of Stars.lrc
# One Direction - Best Song Ever.lrc
# One Direction - Kiss You.lrc
# DNCE - Cake By The Ocean.lrc
# Nickelback - How You Remind Me.lrc
# Shakira - Try Everything.lrc
# Becky G - Shower.lrc
# James Arthur - Say You Won't Let Go.lrc
# Taylor Swift - You Belong With Me.lrc
# Justin Bieber - Never Let You Go.lrc
# Ariana Grande - Dangerous Woman.lrc
# Justin Bieber - Mistletoe.lrc
# Drake - Started From the Bottom (Explicit).lrc
# Capital Cities - Safe and Sound.lrc
# Beyoncé - Irreplaceable.lrc
# Bruno Mars - Just the Way You Are.lrc
# Avril Lavigne - Girlfriend.lrc
# Adele - Send My Love (To Your New Lover).lrc
# Imagine Dragons - Demons.lrc
# Justin Bieber - Love Me.lrc
# Miley Cyrus - The Climb (Live).lrc
# The Pussycat Dolls - Buttons.lrc
# Avicii - Waiting for Love.lrc
# Scorpions - Wind Of Change.lrc
# Beyoncé - If I Were a Boy.lrc
# Adele - Hello.lrc
# Black Eyed Peas - I Gotta Feeling.lrc
# Eminem - Without Me.lrc
# Avril Lavigne - Wish You Were Here.lrc
# Miley Cyrus - 7 Things (Single Version).lrc
# Bruno Mars - It Will Rain.lrc
# Eminem - Not Afraid.lrc
# Outkast - Hey Ya!.lrc
# Bruno Mars - The Lazy Song.lrc
# Redfoo - New Thang.lrc
# Ariana Grande - Focus.lrc
# Akon - Lonely.lrc
# P!NK - Try.lrc
# One Direction - Night Changes.lrc
# The Cranberries - Zombie.lrc
# Demi Lovato - Give Your Heart a Break.lrc
# Justin Timberlake - CAN'T STOP THE FEELING!.lrc
# Bruno Mars - When I Was Your Man.lrc
# Linkin Park - What I've Done.lrc
# Katy Perry - Roar.lrc
# Katy Perry - Unconditionally.lrc
# Akon - Right Now(Na Na Na).lrc
# Flo Rida - Good Feeling.lrc
# Alan Walker - Faded.lrc
# Jason Mraz - I'm Yours.lrc
# Christina Perri - Jar of Hearts.lrc
# Beyoncé - Halo.lrc
# Sigma - Nobody To Love (Extended Mix).lrc
# Taylor Swift - We Are Never Ever Getting Back Together.lrc
# Meghan Trainor - NO.lrc
# Taylor Swift - Mine.lrc
# Bruno Mars - Treasure.lrc
# Guns N' Roses - November Rain.lrc
# A-Ha - Take on Me.lrc
# Hoobastank - The Reason.lrc
# Guns N' Roses - Don't Cry (Original).lrc
# One Direction - Live While We're Young.lrc
# Demi Lovato - Heart Attack.lrc
# twenty one pilots - Stressed Out.lrc
# Kesha - TiK ToK.lrc
# Aqua - Barbie Girl.lrc
# Nelly Furtado - Say It Right (Radio Edit).lrc
# Europe - The Final Countdown.lrc
# Lady Gaga - Alejandro.lrc
# Sia - The Greatest.lrc
# Sean Paul - She Doesn't Mind.lrc
# Black Eyed Peas - Boom Boom Pow.lrc
# Katy Perry - Wide Awake.lrc
# Eminem - The Real Slim Shady.lrc
# Selena Gomez - Same Old Love.lrc
# Rihanna - Only Girl (In The World).lrc
# Bruno Mars - Grenade.lrc
# Imagine Dragons - It's Time.lrc
# Ed Sheeran - Shape of You.lrc
# Coldplay - Adventure Of A Lifetime.lrc
# Backstreet Boys - I Want It That Way.lrc
# Michael Jackson - They Don't Care About Us.lrc
# Toni Braxton - Un-Break My Heart (Album Version).lrc
# System of A Down - Chop Suey!.lrc
# Ellie Goulding - Burn.lrc
# Magic! - Rude.lrc
# One Direction - Perfect.lrc
# Miley Cyrus - Wrecking Ball.lrc
# Kelly Clarkson - Stronger (What Doesn't Kill You).lrc
# Maroon 5 - She Will Be Loved.lrc
# Black Eyed Peas - Pump It (po_clean_edit).lrc
# Justin Bieber - One Time.lrc
# Ed Sheeran - Photograph.lrc
# Justin Bieber - One Less Lonely Girl.lrc
# Bloodhound Gang - The Bad Touch.lrc
# Pitbull - I Know You Want Me (Calle Ocho) (More English Radio Edit).lrc
# Sam Smith - I'm Not The Only One.lrc
# Justin Bieber - Company.lrc
# twenty one pilots - Ride.lrc
# Bonnie Tyler - Total Eclipse Of The Heart.lrc
# Wiz Khalifa - Black And Yellow.lrc
# Lukas Graham - 7 Years.lrc
# Chris Brown - Turn Up the Music.lrc
# Eminem - When I'm Gone.lrc
# Foster The People - Pumped Up Kicks.lrc
# Lana Del Rey - Young And Beautiful.lrc
# Katy Perry - The One That Got Away.lrc
# Taylor Swift - Shake It Off.lrc

# %%
import csv

with open(output_path + os.sep + "metadata.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    # Write header
    writer.writerow(["file_name", "text"])
    # Write each segment's data
    for i in range(len(files)):
        writer.writerow([files[i], lines[i]])
